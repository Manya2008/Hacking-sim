# %%
import random 
number= random.randint(1,10)# generates random numbers
#print(number) #shows random number for test

username=input("Who do you want to hack ")#username source

print("hacking ",username,". Pls wait now. Pls, I am slow....")

dollar=int(input("How much money do you want to hack? "))#Question for money

infiite = input("Infinite tries to hack? ")#Question for infinite tries

if infiite == "yes" : # if answer is yes

  Guess=int(input("The hacking password is between 1-10 Currently hacking ")) # asks for input

  while Guess != number : # if wrong it continues to ask

    print("wrong try again!")
    Guess=int(input("The hacking password is between 1-10 Currently hacking "))

  print("Yeah that is correct! You hacked",dollar,"dollars from", username)# correct

if infiite == "Yes" :

  Guess=int(input("The hacking password is between 1-10 Currently hacking "))

  while Guess != number :

    print("wrong try again!")
    Guess=int(input("The hacking password is between 1-10 Currently hacking "))

  print("Yeah that is correct! You hacked",dollar,"dollars from", username)

if infiite == "No": # if answer is no
  Guess=int(input("The hacking password is between 1-10 Currently hacking ")) # you know the drill

  if Guess == number : # if correct

    print("Yeah that is correct! You hacked",dollar,"dollars from", username)

  else : # if not
    print("Wrong! The number is ",+ number,"Hacking failed! You are such a noob!")

if infiite == "no":
  Guess=int(input("The hacking password is between 1-10 Currently hacking "))

  if Guess == number :

   print("Yeah that is correct! You hacked",dollar,"dollars from", username)

  else :
        print("Wrong! The number is ",+ number,"Hacking failed! You are such a noob!")
